# %% [markdown]
# ## Terminology:
#
# ### Labels:
# It the variable that we are predicting. Ex: spam/not spam in email filter model (supervised learning).
#
# ### Features:
# - Features are the input variables that describe our data. Ex: subjectLine, toAddress, fromAddress, etc., in the email filter model.
#
# ### Example:
# - An example is a particular instance of data.
# #### Labelled example:
# - It contains both the labels and the features. It is used for training the model.
# *labeled examples: {features, label}: (x, y)*
# #### Unlabelled example:
# - It contains only the features. It is used for testing the model.
# *unlabeled examples: {features, ?}: (x, ?)*
#
# ### Models:
# - Model define the relationship between features and labels. There are two phases in model's life,
#     - **Training**  - training the model with labeled data
#     - **Inference**  - testing the model with unlabeled data

# %% [markdown]
# ## Linear Regression:
#
# ### Example:
# ![image.png](attachment:image.png)
#
# The equation for slope is,
#     y = mx + b
#
# In machine learning, we will write this equation as,
#     ![image-3.png](attachment:image-3.png)
#
# If the model uses more than one feature, the equation will be written as,
#     ![image-4.png](attachment:image-4.png)
#
# ## Empirical Rish Minimization:
#
# In supervised learning, a machine learning algorithm builds a model by examining many examples and attempting to find a model that minimizes loss; this process is called empirical risk minimization.
#
# ## Loss:
#
# Loss is the penalty for a bad prediction. It is a number indication how bad the prediction was for a single example.
# ![image-5.png](attachment:image-5.png)
#
# ## Squared Loss:
#
# It is a Loss function used to determine squared difference between the predicted and actual value. It is also called L<sub>2</sub> loss.
#
#   = the square of the difference between the label and the prediction
#   = (observation - prediction(x))2
#   = (y - y')2
#
# ## Mean Square Error (MSE)
#
# It is the average squared loss over the entire dataset. It is calculated by summing up all the squared losses and diving it by the number of examples provided.
#
# ![image-6.png](attachment:image-6.png)
